# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib_inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

warnings.simplefilter('ignore')

# %%
df_train = pd.read_csv("../dataset/train.csv")
display(df_train.head().append(df_train.tail()))
print(df_train.info())
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# ...

# %%
df_test = pd.read_csv("../dataset/test.csv")
display(df_test.head().append(df_test.tail()))
print(df_test.info())
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      3000888  2017-08-16          1                  AUTOMOTIVE            0
# 1      3000889  2017-08-16          1                   BABY CARE            0
# 2      3000890  2017-08-16          1                      BEAUTY            2
# 3      3000891  2017-08-16          1                   BEVERAGES           20
# 4      3000892  2017-08-16          1                       BOOKS            0
# 28507  3029395  2017-08-31          9                     POULTRY            1
# 28508  3029396  2017-08-31          9              PREPARED FOODS            0
# 28509  3029397  2017-08-31          9                     PRODUCE            1
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399  2017-08-31          9                     SEAFOOD            0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# ...

# %% [markdown]
# sample_submission：提出データフォーマット

# %%
df_sample = pd.read_csv("../dataset/sample_submission.csv")
display(df_sample.head().append(df_sample.tail()))
del(df_sample)
# Out:
#             id  sales
# 0      3000888    0.0
# 1      3000889    0.0
# 2      3000890    0.0
# 3      3000891    0.0
# 4      3000892    0.0
# 28507  3029395    0.0
# 28508  3029396    0.0
# 28509  3029397    0.0
# 28510  3029398    0.0
# 28511  3029399    0.0

# %% [markdown]
# holidays_events：休日とイベント日程

# %%
df_holiday = pd.read_csv("../dataset/holidays_events.csv")
display(df_holiday.head().append(df_holiday.tail()))
print(df_holiday.info())
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# 345                      Navidad-3        False
# 346                      Navidad-2        False
# ...

# %% [markdown]
# oil.csv：石油価格

# %%
df_oil = pd.read_csv("../dataset/oil.csv")
display(df_oil.head().append(df_oil.tail()))
print(df_oil.info())
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB
# None

# %% [markdown]
# stores.csv：都市毎のストアデータ

# %%
df_store = pd.read_csv("../dataset/stores.csv")
display(df_store.head().append(df_store.tail()))
print(df_store.info())
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
# 53         54      El Carmen                          Manabi    C        3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ...

# %% [markdown]
# transactions.csv：日毎の取引量

# %%
df_trans = pd.read_csv("../dataset/transactions.csv")
display(df_trans.head().append(df_trans.tail()))
print(df_trans.info())
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB
# None

# %%
# df_trainにyear列追加
df_train["year"] = df_train["date"].str[:4]
display(df_train.head())
# Out:
#    id        date  store_nbr      family  sales  onpromotion  year
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  2013
# 1   1  2013-01-01          1   BABY CARE    0.0            0  2013
# 2   2  2013-01-01          1      BEAUTY    0.0            0  2013
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  2013
# 4   4  2013-01-01          1       BOOKS    0.0            0  2013

# %%
# df_trainを可視化
sns.set_style("white")
df_date = df_train[["date", "sales"]].groupby("date").sum()
df_date.plot(y="sales", figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# df_trainを年毎に可視化
sns.set_style("white")
for year, df_year in df_train.groupby("year"):
    df_date = df_year[["date", "sales"]].groupby("date").sum()
    df_date.plot(y="sales", figsize=(15,5))

# %%
# df_trainをfamilyについて可視化
df_family = df_train[["sales", "family"]].groupby("family").sum()
df_family.sort_values("sales", ascending=True, inplace=True)
sns.set_style("white")
plt.bar(df_family.index,df_family["sales"])
ax.set_xlabel("Family")
ax.set_ylabel("Sales")
plt.xticks(rotation=90)
plt.show()

# %%
# df_transにyear列追加
df_trans["year"] = df_trans["date"].str[:4]
display(df_trans.head())
# Out:
#          date  store_nbr  transactions  year
# 0  2013-01-01         25           770  2013
# 1  2013-01-02          1          2111  2013
# 2  2013-01-02          2          2358  2013
# 3  2013-01-02          3          3487  2013
# 4  2013-01-02          4          1922  2013

# %%
# df_transを可視化
sns.set_style("white")
df_date = df_trans[["date", "transactions"]].groupby("date").sum()
df_date.plot(y="transactions", figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# df_transを年毎に可視化
sns.set_style("white")
for year, df_year in df_trans.groupby("year"):
    df_date = df_year[["date", "transactions"]].groupby("date").sum()
    df_date.plot(y="transactions", figsize=(15,5))

# %% [markdown]
# 毎年1/1は売り上げが極端に少ない（休み？）<br>
# 年末は売り上げが極端に上がる

# %%
# df_oilにyearカラムを追加, NaN=>0.0
df_oil["year"] = df_oil["date"].str[:4]
df_oil.fillna(0, inplace=True)
display(df_oil.head())
# Out:
#          date  dcoilwtico  year
# 0  2013-01-01        0.00  2013
# 1  2013-01-02       93.14  2013
# 2  2013-01-03       92.97  2013
# 3  2013-01-04       93.12  2013
# 4  2013-01-07       93.20  2013

# %%
# 石油価格と売上の可視化
df_oil_year = df_oil[["year", "dcoilwtico"]].groupby("year").mean()
df_sales_year = df_train[["year", "sales"]].groupby("year").sum()
# 2017の売り上げは8月までしかないので可視化に含めない
df_oil_year = df_oil_year[df_oil_year.index != "2017"]
df_sales_year = df_sales_year[df_sales_year.index != "2017"]
fig, ax1 = plt.subplots(1,1,figsize=(10,8))
ax2 = ax1.twinx()
ax1.bar(df_oil_year.index, df_oil_year["dcoilwtico"],label="oil", color="lightblue")
ax2.plot(df_sales_year.index, df_sales_year["sales"],linestyle="solid",marker="*",label="sales")
handler1, label1 = ax1.get_legend_handles_labels()
handler2, label2 = ax2.get_legend_handles_labels()
ax1.legend(handler1+handler2,label1+label2,borderaxespad=0)
ax1.grid(True)
fig.show()

# %% [markdown]
# 石油価格と売り上げには負の相関がある？

# %%
# df_trainにholiday情報をマージ
df_train = df_train.merge(df_holiday, on="date", how="left")
display(df_train.head().append(df_train.tail()))
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# 3054343  3000883  2017-08-15          9                     POULTRY   438.133
# 3054344  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3054345  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3054346  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3054347  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year     type    locale locale_name  \
# ...

# %%
df_holiday["type"].unique()
# Out:
# array(['Holiday', 'Transfer', 'Additional', 'Bridge', 'Work Day', 'Event'],
#       dtype=object)

# %%
df_holiday.loc[df_holiday["locale"] == "National", "type"].unique()
# Out:
# array(['Holiday', 'Transfer', 'Additional', 'Bridge', 'Work Day', 'Event'],
#       dtype=object)

# %%
# holidayのtypeごとの平均sales
df_train["type"].fillna("Normal Day", inplace=True)
df_holiday_sales = df_train[["sales", "type"]].groupby(["type"], as_index=False).mean()
df_holiday_sales.sort_values(by="sales", inplace=True)
plt.bar(df_holiday_sales["type"], df_holiday_sales["sales"])
plt.show()

# %% [markdown]
# 意外とHolidayが少ない？？？

# %%
# holidayのtype,storeごとの平均sales
for year, df_store in df_train.groupby("store_nbr"):
    df_holiday_sales = df_store[["sales", "type"]].groupby(["type"], as_index=False).mean()
    df_holiday_sales.sort_values(by="sales", inplace=True)
    plt.bar(df_holiday_sales["type"], df_holiday_sales["sales"])
    plt.show()

# %%
df_train["date"] = pd.to_datetime(df_train["date"])
df_train["DoW"] = df_train["date"].dt.dayofweek
df_week_sales = df_train[["sales", "DoW"]].groupby(["DoW"], as_index=False).mean()
plt.bar(df_week_sales["DoW"], df_week_sales["sales"])
plt.xticks([0,1,2,3,4,5,6], ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"])
plt.show()

# %% [markdown]
# やはり土日が多い、平日は大差なさそうだけど木曜が少ない？
